# %%
import pandas as pd
import json
import re
from typing import List, Optional
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api.formatters import TextFormatter
import requests
# Out:
# /Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/venv/lib/python3.11/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.18) or chardet (5.2.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %% [markdown]
# TODO:
# - get all videos on the Neo4j youtube channel
# - upload list of videos to gcp bucket
# - pull video titles and get transcripts of each
# - chunk transcripts
# - upload to graph

# %%
import os

import google_auth_oauthlib.flow
import googleapiclient.discovery
import googleapiclient.errors

# %%
scopes = ["https://www.googleapis.com/auth/youtube.readonly"]

api_service_name = "youtube"
api_version = "v3"
client_secrets_file = os.environ.get("GCP_SERVICE_ACCOUNT_KEY_PATH")
api_key = os.environ.get("YOUTUBE_API_KEY")

# Get credentials and create an API client
flow = google_auth_oauthlib.flow.InstalledAppFlow.from_client_secrets_file(
    client_secrets_file, scopes)
credentials = flow.credentials
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=api_key, credentials=credentials)

request = youtube.search().list(
    part="snippet",
    q="@neo4j"
)
response = request.execute()

print(response['items'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb Cell 4 line 1
#       <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a> # Get credentials and create an API client
#       <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#W4sZmlsZQ%3D%3D?line=8'>9</a> flow = google_auth_oauthlib.flow.InstalledAppFlow.from_client_secrets_file(
#      <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#W4sZmlsZQ%3D%3D?line=9'>10</a>     client_secrets_file, scopes)
# ---> <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#W4sZmlsZQ%3D%3D?line=10'>11</a> credentials = flow.credentials
#      <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#W4sZmlsZQ%3D%3D?line=11'>12</a> youtube = googleapiclient.discovery.build(
#      <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#W4sZmlsZQ%3D%3D?line=12'>13</a>     api_service_name, api_version, developerKey=api_key, credentials=credentials)
#      <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#W4sZmlsZQ%3D%3D?line=14'>15</a> request = youtube.search().list(
#      <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#W4sZmlsZQ%3D%3D?line=15'>16</a>     part="snippet",
#      <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#W4sZmlsZQ%3D%3D?line=16'>17</a>     q="@neo4j"
#      <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#W4sZmlsZQ%3D%3D?line=17'>18</a> )
#
# File ~/Documents/GitHub/Agent-Neo-field/venv/lib/python3.11/site-packages/google_auth_oauthlib/flow.py:301, in Flow.credentials(self)
#     287 @property
#     288 def credentials(self):
#     289     """Returns credentials from the OAuth 2.0 session.
#     290
#     291     :meth:`fetch_token` must be called before accessing this. This method
#    (...)
#     299         ValueError: If there is no access token in the session.
#     300     """
# --> 301     return google_auth_oauthlib.helpers.credentials_from_session(
#     302         self.oauth2session, self.client_config
#     303     )
#
# File ~/Documents/GitHub/Agent-Neo-field/venv/lib/python3.11/site-packages/google_auth_oauthlib/helpers.py:125, in credentials_from_session(session, client_config)
#     122 client_config = client_config if client_config is not None else {}
#     124 if not session.token:
# --> 125     raise ValueError(
#     126         "There is no access token for this session, did you call " "fetch_token?"
#     127     )
#     129 if "3pi" in client_config:
#     130     credentials = external_account_authorized_user.Credentials(
#     131         token=session.token["access_token"],
#     132         refresh_token=session.token.get("refresh_token"),
#    (...)
#     137         scopes=session.scope,
#     138     )
#
# ValueError: There is no access token for this session, did you call fetch_token?

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'PUwUneO0Y0_0iXRhKY_QcU7u54g',
#  'id': {'kind': 'youtube#channel', 'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'},
#  'snippet': {'publishedAt': '2014-12-03T23:18:57Z',
#   'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#   'title': 'Neo4j',
#   'description': 'Neo4j is the Graph Database & Analytics leader. This channel features videos by our Developer Relations, Engineering and ...',
#   'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/BEHbbtI42GHOisSFC2P0SDkPlBO9eofY_vle616iX0ze76HT3_P40AzE9TjGQH2nxsGaWyey9g=s88-c-k-c0xffffffff-no-rj-mo'},
#    'medium': {'url': 'https://yt3.ggpht.com/BEHbbtI42GHOisSFC2P0SDkPlBO9eofY_vle616iX0ze76HT3_P40AzE9TjGQH2nxsGaWyey9g=s240-c-k-c0xffffffff-no-rj-mo'},
#    'high': {'url': 'https://yt3.ggpht.com/BEHbbtI42GHOisSFC2P0SDkPlBO9eofY_vle616iX0ze76HT3_P40AzE9TjGQH2nxsGaWyey9g=s800-c-k-c0xffffffff-no-rj-mo'}},
#   'channelTitle': 'Neo4j',
#   'liveBroadcastContent': 'upcoming',
#   'publishTime': '2014-12-03T23:18:57Z'}}

# %%
channel_request = youtube.channels().list(
    part='snippet',
    id="UCvze3hU6OZBkB1vkhH2lH9Q" # Neo4j channel id
)

channel_response = channel_request.execute()

print(channel_response)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'sM6Mjxe01RLMdKH0-NW7RFKHa38', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'C3w1MrDZesb176j1Xt4dk6DUGOo', 'id': 'UCvze3hU6OZBkB1vkhH2lH9Q', 'snippet': {'title': 'Neo4j', 'description': 'Neo4j is the Graph Database & Analytics leader.  This channel features videos by our Developer Relations, Engineering and Product teams about best practices using Neo4j. Learn more at https://neo4j.com/ If you have technical questions or want to build a local community join https://community.neo4j.com', 'customUrl': '@neo4j', 'publishedAt': '2014-12-03T23:18:57Z', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/BEHbbtI42GHOisSFC2P0SDkPlBO9eofY_vle616iX0ze76HT3_P40AzE9TjGQH2nxsGaWyey9g=s88-c-k-c0x00ffffff-no-rj', 'width': 88, 'height': 88}, 'medium': {'url': 'https://yt3.ggpht.com/BEHbbtI42GHOisSFC2P0SDkPlBO9eofY_vle616iX0ze76HT3_P40AzE9TjGQH2nxsGaWyey9g=s240-c-k-c0x00ffffff-no-rj', 'width': 240, 'height': 240}, 'high': {'url': 'https://yt3.ggpht.com/BEHbbtI42GHOisSFC2P0SDkPlBO9eofY_vle616iX0ze76HT3_P40AzE9TjGQH2nxsGaWyey9g=s800-c-k-c0x00ffffff-no-rj', 'width': 800, 'height': 800}}, 'localized': {'title': 'Neo4j', 'description': 'Neo4j is the Graph Database & Analytics leader.  This channel features videos by our Developer Relations, Engineering and Product teams about best practices using Neo4j. Learn more at https://neo4j.com/ If you have technical questions or want to build a local community join https://community.neo4j.com'}, 'country': 'US'}}]}

# %%
videos_request = youtube.search().list(
    part="id",
    channelId="UCvze3hU6OZBkB1vkhH2lH9Q",
    type="video",
    maxResults=50
)

videos_response = videos_request.execute()

# %%
videos_response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'pO2-wbJUXTvOOvRwgU0spVgwxYc',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'US',
#  'pageInfo': {'totalResults': 1973, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'nxlahA9AHrmQu88pjCG-56TrBec',
#    'id': {'kind': 'youtube#video', 'videoId': 'urO5FyP9PoI'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'f4qSWTBGM9I4Zy2ujR-gT-cvyK0',
#    'id': {'kind': 'youtube#video', 'videoId': 'REVkXVxvMQE'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'CxjrsQeRbkzD4XK2WC91uegrfEw',
#    'id': {'kind': 'youtube#video', 'videoId': 'mMkXnmueasA'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'LlzR-X3sD8-sfcnCCgcVLnfxaF8',
#    'id': {'kind': 'youtube#video', 'videoId': 'nYQLp7itZx8'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '4R2co9P2GJjdRx_2Bod-51WfQ94',
#    'id': {'kind': 'youtube#video', 'videoId': 'o2yujqUGCTw'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'vetKh5-czmh9VSY3pY5ka8_rLSw',
#    'id': {'kind': 'youtube#video', 'videoId': '7NHj09myb5Q'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '5tt0uim6782ZgEDVnv6oZ2K7QoM',
#    'id': {'kind': 'youtube#video', 'videoId': 'KbMHtm3y6PI'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'rR_oxYxeZOrzzHCE3qsbuCh9sl4',
#    'id': {'kind': 'youtube#video', 'videoId': '4wUZXK8KuUc'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'OiH7lCPf0cQEsAQXwGXZHSU2sqk',
#    'id': {'kind': 'youtube#video', 'videoId': 'GV3WCEsHRYI'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '_X1Yfqn5b4h3tFWnJTYTEyg63CA',
#    'id': {'kind': 'youtube#video', 'videoId': 'ZHJ-BrKJ8A4'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'vel0afPb2l2cwDXS1MJ5WuwzGD8',
#    'id': {'kind': 'youtube#video', 'videoId': 'GcaJ-aVLzr4'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'wItjMH62y9UKnPq4fWv7MqmtmSE',
#    'id': {'kind': 'youtube#video', 'videoId': 'HNE-Ctl52hw'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '5bVCIm1ZzJyKF18ZCdXb5wb8WYc',
#    'id': {'kind': 'youtube#video', 'videoId': '5wluUfomasg'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'W2IDRzvStyCYXayzgwY6KrHc400',
#    'id': {'kind': 'youtube#video', 'videoId': '-dCeFEqDkUI'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '4CMMWYLpWDhyZB7WMgeMvRaxmKE',
#    'id': {'kind': 'youtube#video', 'videoId': '60Kb70ci2M0'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'tmLvDoK8HUOkV4t1go8XIjlmdaQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'C_9OgkDWnLE'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '-lwxyqCE-fizcWtsXGJe2nhpKNk',
#    'id': {'kind': 'youtube#video', 'videoId': 'nzBg23aTCAE'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'r6ECE7mqDqb9JIeE2xDW2KhYoGg',
#    'id': {'kind': 'youtube#video', 'videoId': 'NO3C-CWykkY'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '0PKzHi5P_rV-2vJZLBrf_oiBOUc',
#    'id': {'kind': 'youtube#video', 'videoId': 'TO00ELu_uJI'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Y5iMG7WstayeZ7Ew-teWnq3D9-Q',
#    'id': {'kind': 'youtube#video', 'videoId': 'LRQuJtoIW_I'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'cd1ACGM9bx9kVPqhhfhDv9llvD4',
#    'id': {'kind': 'youtube#video', 'videoId': 'j3MTkvLS1PU'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'QNgF9ruUAZ4Yno0_t8p-UQ28szU',
#    'id': {'kind': 'youtube#video', 'videoId': 'jI1pcAT6dAs'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Nz2P5tYgJxs0tCTc5hMe0iK3R1I',
#    'id': {'kind': 'youtube#video', 'videoId': '-7VOIX7YtB4'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ZVBkYWEErHHX47EYAKwSv-mA-kA',
#    'id': {'kind': 'youtube#video', 'videoId': 'XaoF43cFCFQ'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'AVbDg92cqY_2U55badYGDAkQbUE',
#    'id': {'kind': 'youtube#video', 'videoId': 'LmYBF8152F4'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'asCfQKNzN-gzj9bJ-kymgWFEiq4',
#    'id': {'kind': 'youtube#video', 'videoId': 'ml7Mmz2ogXU'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'b59_leL0hdVYV7j5ZkovNEvlg8Y',
#    'id': {'kind': 'youtube#video', 'videoId': 'WVjss62XIG0'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'DN4kvP0OXg_Vz23GdNHqg229d8s',
#    'id': {'kind': 'youtube#video', 'videoId': 'XEXZ7gR2UGM'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'wz-VfhoKOQ51guxM6ViKZr8-GuI',
#    'id': {'kind': 'youtube#video', 'videoId': 'y_BP61zVdPI'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'l6NEhg_oxCIiMxYR0Od3xAF0ze8',
#    'id': {'kind': 'youtube#video', 'videoId': 'LyXyEy7HTLQ'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'gfhpRajGv3S7M2WpH1rCvhIDLqk',
#    'id': {'kind': 'youtube#video', 'videoId': 'tvSgRX9_vP4'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'mLL7szG7dud6Qttmu6F2wkZgNc8',
#    'id': {'kind': 'youtube#video', 'videoId': '2nb2y_ZSdSo'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'WcnOkp2yvk2ajzSF6mm3vpQcn3k',
#    'id': {'kind': 'youtube#video', 'videoId': 'sA3EY5Hq6-E'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'wUYlVjZBLsoHaffWJZSKwUCQySM',
#    'id': {'kind': 'youtube#video', 'videoId': 'Zkgu7YauOfs'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'LkXBPF898YQvOgxRnFQqf5iJMUI',
#    'id': {'kind': 'youtube#video', 'videoId': 'PfySvVqHAWo'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'IM-v7O7ftQRJcJYpOJ81u4marQU',
#    'id': {'kind': 'youtube#video', 'videoId': 'hdZ7aOPvKjQ'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'mGnZhqPNjTzWjXxEC4B_Jg1QlB0',
#    'id': {'kind': 'youtube#video', 'videoId': 'P_2qCZGj430'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'fEACqZKDXWCOSylXzPodjYXWe_c',
#    'id': {'kind': 'youtube#video', 'videoId': 'lnoxoAsWguM'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '-2zVmoc_8v8yeLL-TnzdcLdlQkE',
#    'id': {'kind': 'youtube#video', 'videoId': '89Jk5dEXJIk'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'SYTvqhdl5aZxU8kTOYXcXPG-P38',
#    'id': {'kind': 'youtube#video', 'videoId': 'SWYuUwr1gvA'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Hte4qfbjVdMNeyv-l6aSnB4suT0',
#    'id': {'kind': 'youtube#video', 'videoId': 'bAP5F-etPVs'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'evvN2IRS30rNou6pqjTPynCUArk',
#    'id': {'kind': 'youtube#video', 'videoId': 'kkABEle4V3M'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'luUsf8qNMYWrUk7jIKQelf12LjY',
#    'id': {'kind': 'youtube#video', 'videoId': '0FO81O-nTrc'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'spT6Q_Bekw0aeE9coT58hENLdbY',
#    'id': {'kind': 'youtube#video', 'videoId': 'HobgiHhwRo8'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'MhKY_-rYEPUFr07X6tzkH6V-4_o',
#    'id': {'kind': 'youtube#video', 'videoId': 'rNKLgqU_mu0'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'fFERb9NCGEyLS1euJRz1bLYHG18',
#    'id': {'kind': 'youtube#video', 'videoId': 'ySTbWaVhVpA'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'grbngwvvyZ4nYYQ2TSycvcTZoPo',
#    'id': {'kind': 'youtube#video', 'videoId': '-E2nWT3LyOM'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'db62XeM5t3H892x01VKtbDo9-XQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'AMrXgoB3iBg'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'By6xzvCUM3uR8tFPJZnFJsC0Dnk',
#    'id': {'kind': 'youtube#video', 'videoId': 'xK7K-4Te8Bs'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'YCH1DAgG9ZYIDx4NIJdgDIJk9b8',
#    'id': {'kind': 'youtube#video', 'videoId': 'wO5AI1oDGjQ'}}]}

# %%
def get_videos() -> List[str]:

    videos = []
    total_results = 0
    next_page_token = None

    def get_next_videos(next_page_token: str = None, total_results: int = None, videos: List = None) -> None:

        if not next_page_token:

            videos_request = youtube.search().list(
                part="id",
                channelId="UCvze3hU6OZBkB1vkhH2lH9Q",
                type="video",
                maxResults=50
            )
        else:
            videos_request = youtube.search().list(
                part="id",
                channelId="UCvze3hU6OZBkB1vkhH2lH9Q",
                type="video",
                maxResults=50,
                pageToken=next_page_token
            )

        videos_response = videos_request.execute()

        if total_results == 0:
            total_results = videos_response['pageInfo']['totalResults']

        next_page_token = videos_response['nextPageToken']
        print(next_page_token)

        videos += [x['id']['videoId'] for x in videos_response['items']]


    while total_results >= len(videos):

        get_next_videos(next_page_token=next_page_token, total_results=total_results, videos=videos)
        print("total results: ", total_results)
        print("ids retrieved: ", len(videos))

    return videos

# %%
videos = get_videos()
# Out:
# total results:  0
# ids retrieved:  50

# %%
def get_next_videos(next_page_token: str = None, total_results: int = -1, videos: List = []) -> List[str]:

    if total_results == len(videos):
        print("complete")
    
    if not next_page_token:

        videos_request = youtube.search().list(
            part="id",
            channelId="UCvze3hU6OZBkB1vkhH2lH9Q",
            type="video",
            maxResults=50
        )

    else:
        videos_request = youtube.search().list(
            part="id",
            channelId="UCvze3hU6OZBkB1vkhH2lH9Q",
            type="video",
            maxResults=50,
            pageToken=next_page_token
        )

    videos_response = videos_request.execute()

    if total_results == -1:
        total_results = videos_response['pageInfo']['totalResults']
        print('total results set: ', total_results)

    next_page_token = videos_response['nextPageToken']
    # print(next_page_token)

    videos += [x['id']['videoId'] for x in videos_response['items']]

    print("total results: ", total_results)
    print("ids retrieved: ", len(videos), "\n")

    get_next_videos(next_page_token=next_page_token, total_results=total_results, videos=videos)


    return videos

# %%
vids = get_next_videos()
# Out:
# total results set:  1983
# total results:  1983
# ids retrieved:  50
#
# total results:  1983
# ids retrieved:  100
#
# total results:  1983
# ids retrieved:  150
#
# total results:  1983
# ids retrieved:  200
#
# total results:  1983
# ids retrieved:  250
#
# total results:  1983
# ids retrieved:  300
#
# total results:  1983
# ids retrieved:  350
#
# total results:  1983
# ids retrieved:  400
#
# total results:  1983
# ids retrieved:  450
#
# total results:  1983
# ids retrieved:  500
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> vids = get_next_videos()
#
# /Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb Cell 12 line 3
#      <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#X15sZmlsZQ%3D%3D?line=34'>35</a> print("total results: ", total_results)
#      <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#X15sZmlsZQ%3D%3D?line=35'>36</a> print("ids retrieved: ", len(videos), "\n")
# ---> <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#X15sZmlsZQ%3D%3D?line=37'>38</a> get_next_videos(next_page_token=next_page_token, total_results=total_results, videos=videos)
#      <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#X15sZmlsZQ%3D%3D?line=40'>41</a> return videos
#
# /Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb Cell 12 line 3
#      <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#X15sZmlsZQ%3D%3D?line=34'>35</a> print("total results: ", total_results)
#      <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#X15sZmlsZQ%3D%3D?line=35'>36</a> print("ids retrieved: ", len(videos), "\n")
# ---> <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#X15sZmlsZQ%3D%3D?line=37'>38</a> get_next_videos(next_page_token=next_page_token, total_results=total_results, videos=videos)
#      <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#X15sZmlsZQ%3D%3D?line=40'>41</a> return videos
#
#     [... skipping similar frames: get_next_videos at line 38 (7 times)]
#
# /Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb Cell 12 line 3
#      <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#X15sZmlsZQ%3D%3D?line=34'>35</a> print("total results: ", total_results)
#      <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#X15sZmlsZQ%3D%3D?line=35'>36</a> print("ids retrieved: ", len(videos), "\n")
# ---> <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#X15sZmlsZQ%3D%3D?line=37'>38</a> get_next_videos(next_page_token=next_page_token, total_results=total_results, videos=videos)
#      <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#X15sZmlsZQ%3D%3D?line=40'>41</a> return videos
#
# /Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb Cell 12 line 3
#      <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#X15sZmlsZQ%3D%3D?line=26'>27</a>     total_results = videos_response['pageInfo']['totalResults']
#      <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#X15sZmlsZQ%3D%3D?line=27'>28</a>     print('total results set: ', total_results)
# ---> <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#X15sZmlsZQ%3D%3D?line=29'>30</a> next_page_token = videos_response['nextPageToken']
#      <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#X15sZmlsZQ%3D%3D?line=30'>31</a> # print(next_page_token)
#      <a href='vscode-notebook-cell:/Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/src/main/notebooks/youtube/youtube.ipynb#X15sZmlsZQ%3D%3D?line=32'>33</a> videos += [x['id']['videoId'] for x in videos_response['items']]
#
# KeyError: 'nextPageToken'

# %%
channel_id = "UCvze3hU6OZBkB1vkhH2lH9Q"
api_key = os.environ.get("YOUTUBE_API_KEY")
uploads_id = "UUvze3hU6OZBkB1vkhH2lH9Q"

# %%
address = f"https://www.googleapis.com/youtube/v3/channels?id={channel_id}&key={api_key}&part=contentDetails"
req = requests.get(address)
data = req.json()

# %%
data
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'GAjRI1ohn2N7TwCkG6zy3YoEgkg',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'ShFBCyiIcf4MH1THCp3SFC3cjg0',
#    'id': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUvze3hU6OZBkB1vkhH2lH9Q'}}}]}

# %%
uploads_id = data['items'][0]['contentDetails']['relatedPlaylists']['uploads']
uploads_id
# Out:
# 'UUvze3hU6OZBkB1vkhH2lH9Q'

# %%
address = f"https://www.googleapis.com/youtube/v3/playlistItems?playlistId={uploads_id}&key={api_key}&part=snippet&maxResults=50"
vid_req = requests.get(address)
vids = vid_req.json()

# %%
vids
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': 'xLN2HUF0l28UphoKOZRhfYbH8dg',
#  'nextPageToken': 'EAAaIVBUOkNESWlFRFF4TlRJMVJEWkNSakE0TWtSRlJqZ29BUQ',
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': 'AHfzWRLa5mpZFHyj7yDIPPX3RLY',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLkJQOW5BVFczeV9N',
#    'snippet': {'publishedAt': '2023-11-02T13:55:45Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'NODES 2023 - Fluffy and Fido on the Go: Applying Graph Data and AI to Hack Pet Travel',
#     'description': 'Ever grappled with the difficulties of traveling with your cherished pet? Discovering the perfect location can require considerable research as you scour the web for pet-friendly hotels, restaurants, green spaces, and more. Furthermore, the urgency of finding an available veterinarian nearby in the event of a pet medical emergency can add to the stress.\n\nIn this session, the presenters will guide you on how to leverage publicly-available data to locate pet-friendly accommodations, store this information in Neo4j, and combine Neo4j with Artificial Intelligence to find ideal places for you and your pet to stay, dine, and enjoy. The presenters will build an application using Spring Boot and Spring AI, deploy it to Azure Spring Apps, and demonstrate both the app and the Neo4j Bloom visualization tool for additional data insights.\n\nBy attending this session, you will learn how to streamline your pet travel planning process, allowing more time to enjoy your adventure with your four-legged friend.\nSlides: https://bit.ly/49lhPla\n\n #Introductory #Java #AuraDB #API #Visualization #Cloud #Travel #Recommendations #Neo4j',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BP9nATW3y_M/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BP9nATW3y_M/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BP9nATW3y_M/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/BP9nATW3y_M/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/BP9nATW3y_M/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 0,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'BP9nATW3y_M'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'AYVQx7TzkjQEZxZmfKpX7wuo7no',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLk1RVFZER09pV0JZ',
#    'snippet': {'publishedAt': '2023-11-02T12:46:06Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'NODES 2023 - Graphs vs. Tables: Compare the Reality of Data Around You',
#     'description': "Not all data models are created equal. Some are more rigid and structured, while others are more flexible and easy to understand.\n\nIn this session, Kateryna compares data models and reveals the effectiveness of graphs versus tables in revealing patterns. You'll gain a clear understanding of the difference between the two data models and how the graph view allows you to uncover hidden patterns and unlock valuable insights much more intuitively compared to the table view.\n\nSlides: https://bit.ly/3MpVHvY\n\n #Intermediate #Analytics #Visualization #KnowledgeGraph #Knowledge Graph #General #recommendations  #Socialmedia #ArtificialIntelligence #Analytics #LifeSciences",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/MQTVDGOiWBY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/MQTVDGOiWBY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/MQTVDGOiWBY/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/MQTVDGOiWBY/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/MQTVDGOiWBY/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 1,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'MQTVDGOiWBY'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'ddAYbPAcQf4-AoI3j4Zm6F_1xO0',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLnZ2bjFXVWdxeHFN',
#    'snippet': {'publishedAt': '2023-11-02T12:43:59Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'NODES 2023 - Query Logs as a Graph',
#     'description': "How can query logs be efficiently stored as a graph? \n\nIn this session, you'll learn how Sebastian, our very own Ops Manager, uses Neo4j to ingest thousands of queries per second and leverage graphs to aggregate, explore, and present large volumes of queries. \n\nAs one of the engineers behind the solution, Sebastian will take you on a technical deep-dive of the design and implementation that the team arrived at.\n\nSlides: https://bit.ly/3sqFq2W\n\n#Intermediate #Database #Cypher #General #Neo4j #Graphdatabase",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vvn1WUgqxqM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vvn1WUgqxqM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vvn1WUgqxqM/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/vvn1WUgqxqM/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/vvn1WUgqxqM/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 2,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'vvn1WUgqxqM'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'gZ2k4556Xlsvzt-f8FpO1r3pXzs',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLjcwVjlUSVl2cXJ3',
#    'snippet': {'publishedAt': '2023-11-02T12:42:51Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'NODES 2023 - Create Graph Dashboards With LLM Powered Natural Language Queries',
#     'description': "In this session, Niels will demonstrate how to use NeoDash and OpenAI to create Neo4j dashboards with natural language. Using a brand new plugin, you can visualize Neo4j data in tables, graphs, maps, and more – without writing any Cypher!\n\nThe session is divided into three parts:\n1. Getting started with NeoDash, an open-source tool for visualizing Neo4j data.\n2. How to set up the natural language queries extension with OpenAI.\n3. Tips and tricks for prompting.\n\nAfter this session, you'll be able to start using NeoDash to visualize your graph faster than ever, combining the power of Cypher and LLMs.\n\nSlides: https://bit.ly/3skPYRh\n\n #Intermediate #Visualization #LLM #Cypher #General\n#graphdatascience #Neo4j #LLMs",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/70V9TIYvqrw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/70V9TIYvqrw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/70V9TIYvqrw/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/70V9TIYvqrw/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/70V9TIYvqrw/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 3,
#     'resourceId': {'kind': 'youtube#video', 'videoId': '70V9TIYvqrw'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'dSD42yPHcSUjHvKbIscvAuwh4uI',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLnBRV0VncE53WTJ3',
#    'snippet': {'publishedAt': '2023-11-02T12:39:39Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'NODES 2023 - Jump Starting Graph Analytics With GDS Python Client Data Loading',
#     'description': 'Join Adam on a journey to explore the ease of initiating and experimenting with Neo4j Graph Data Science through its Python client surface. This platform provides multiple convenient methods for constructing graphs with data science capabilities, offering excellent performance.\n\nWhether you are projecting data from your Neo4j database, importing any NetworkX graph, utilizing any dataset from the Open Graph Benchmark, or even bringing in data from Pandas DataFrames, the GDS Python client has you covered.\n\nIn this session, Adam will guide you through some of these import capabilities and illustrate how simple it is to start working with graph data science in 2023. Get ready to dive into the world of efficient graph analytics!\n\nSlides: https://bit.ly/3sgtsJc\n\n #Introductory # Intermediate #GraphDataScience #Analytics #Database #Machine Learning # tools #Python #AuraDS # Performance #Neo4j',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pQWEgpNwY2w/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/pQWEgpNwY2w/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/pQWEgpNwY2w/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/pQWEgpNwY2w/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/pQWEgpNwY2w/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 4,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'pQWEgpNwY2w'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'OF5H72-0rJtKJkl7raj93DgFBxw',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLkRRLVNTaENHVnpz',
#    'snippet': {'publishedAt': '2023-11-02T12:38:06Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'NODES 2023 - Improving Data Quality With Cypher Types',
#     'description': 'Having a schema-flexible database is great, especially for development, but we all know the hassle that inconsistent data in production can cause! The introduction of Type Constraints gives us the power to make sure our properties keep in line with what we expect to see, and the helper expressions and functions that were introduced alongside them give us the ability to clean up our data before we enforce them.\n\nIn this talk, Cypher Engineers Gemma and Louise will introduce you to Cypher Types and how to work with the new Type Constraints and Type Predicate Expressions. You will learn how to use them, what to watch out for along the way, and, ultimately, how they significantly improve the quality of your data.\n\nSlides: https://bit.ly/45VNSFg\n\n #Intermediate #Cypher #Recommendations #graphdatabase #Neo4j',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DQ-SShCGVzs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/DQ-SShCGVzs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/DQ-SShCGVzs/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/DQ-SShCGVzs/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/DQ-SShCGVzs/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 5,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'DQ-SShCGVzs'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'MP0qnO_zdg2dmOESLn0jYMOQo3U',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLlpuZDRrNjRKUkZj',
#    'snippet': {'publishedAt': '2023-11-02T11:53:55Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'NODES 2023 - Advanced Pathfinding, Simple Queries, and Efficient Execution – Pick Three',
#     'description': "Join Finbar and Bastien, two Neo4j engineers trying to find their way home using the UK rail network timetable Neo4j database and the new\xa0Cypher\xa0quantified path patterns. In the process, you'll learn how the new syntax makes it easier to write advanced path-finding queries, look under the hood to see how you can improve performance by eliminating unnecessary graph traversals, and get a preview of how quantified path patterns can get them home faster using the upcoming enhancements to shortest paths.\n\nLearn more about Neo4j: https://bit.ly/47jnNRL\n\n#Neo4j #Cypher #graphdatabase",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Znd4k64JRFc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Znd4k64JRFc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Znd4k64JRFc/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/Znd4k64JRFc/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/Znd4k64JRFc/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 6,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'Znd4k64JRFc'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'eFlsHzVgqHlcEhM5OjzHM_bIUBE',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLjlEeHdnSUtWU0hZ',
#    'snippet': {'publishedAt': '2023-11-02T08:47:48Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'Going Meta - A Series on Graphs, Semantics and Knowledge Episode 22',
#     'description': 'Episode 22 of Going Meta – a series on graphs, semantics and knowledge Jesús Barrasa: https://twitter.com/BarrasaDV\n\nRepository: https://github.com/jbarrasa/goingmeta\n\nKnowledge Graph Book: https://neo4j.com/knowledge-graphs-practitioners-guide/\n\nCheck out https://community.neo4j.com/ for questions and discussions around Neo4j\n\n#neo4j #graphdatabase #knowledgegraphs #knowledgegraph #semantic #ontology',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9DxwgIKVSHY/default_live.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/9DxwgIKVSHY/mqdefault_live.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/9DxwgIKVSHY/hqdefault_live.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/9DxwgIKVSHY/sddefault_live.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/9DxwgIKVSHY/maxresdefault_live.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 7,
#     'resourceId': {'kind': 'youtube#video', 'videoId': '9DxwgIKVSHY'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'ZS81H4o6m2qT_SFEy95NxmpKLhs',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLm01MUR0cHBiMmgw',
#    'snippet': {'publishedAt': '2023-11-01T22:43:31Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'NODES 2023 - Build Apps with the New GenAI Stack from Docker, LangChain, Ollama, and Neo4j',
#     'description': 'From Zero to Database-backed Support Bot - Using the new GenAI Stack from Docker, LangChain, Ollama, and Neo4j With the breakthrough of large language models, adding generative AI capabilities to your applications is now possible for every developer. But where to start? In a partnership between Docker, Neo4j, LangChain, and Ollama we created a GenAI Stack for building database backed GenAI applications. Just with a single "docker-compose up", you get them up and running and can start importing data and creating vector embeddings as well as using an example chatbot application to answer natural language questions using a combination of a Large Language Model and a Knowledge Graph. In this session, we will look behind the scenes into the containers of the GenAI Stack, how they work together and how the LangChain and Streamlit Python apps are implemented. We will use data from StackOverflow, so you can fetch topics that you\'re interested in. But we will not stop there! Based on the existing code we will build and run our own GenAI app that extends the existing functionality and thanks to the quick Docker setup, you can code along. This should give you the setup, confidence and convenience to get going with your first applications that use large language models.\n\nLearn more: https://bit.ly/3Q4Ug8j\n\n#GenAI @DockerIo @LangChain #LLMs #Graphdatabase',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/m51Dtppb2h0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/m51Dtppb2h0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/m51Dtppb2h0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/m51Dtppb2h0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/m51Dtppb2h0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 8,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'm51Dtppb2h0'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'CW8LOyQQGx1GHkTr7HjvQjsnEMY',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLl9jQzJQb09KSFFj',
#    'snippet': {'publishedAt': '2023-11-01T22:41:36Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'NODES 2023 - Brief Introduction to The New Parallel Runtime in Neo4j',
#     'description': 'Historically Neo4j has been optimized for single-threaded workloads, meaning that it allows multiple queries to run concurrently to achieve a large amount of work in aggregate. However when it comes to more analytical-type of workloads running on a system with an abundance of CPU cores, forcing all queries to run on a single execution thread is a disadvantage. The new parallel runtime is meant to bridge this gap by allowing a single query to be executed on multiple execution threads.\n\nLearn more about Neo4j: https://bit.ly/47jnNRL\n\n#ParallelRuntime #Neo4j #graphdatabase',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_cC2PoOJHQc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_cC2PoOJHQc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_cC2PoOJHQc/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/_cC2PoOJHQc/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/_cC2PoOJHQc/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 9,
#     'resourceId': {'kind': 'youtube#video', 'videoId': '_cC2PoOJHQc'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'Khh5Or66y02HebegKLGGaJLuzWM',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLlVHdDN1MGh0VG1r',
#    'snippet': {'publishedAt': '2023-11-01T22:40:08Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'NODES 2023 - Driving Cancer Data Interoperability: Python, Liquibase, and Neo4j in Action at the MDB',
#     'description': "Accurately reflecting the evolving data models, mappings, and terminology of the National Cancer Institute's Cancer Research Data Commons (CRDC) in the Metamodel Database (MDB) is crucial for cancer data interoperability. In this session, Nelson and Mark will demonstrate how to use Liquibase, Neo4j, & Python to manage changes in Neo4j databases like the MDB efficiently. You'll learn how to leverage the Liquichange Python package to generate Liquibase Changelogs with Cypher queries from data model files and implement Liquibase with Neo4j, which provides version control, change previewing, and integration with CI/CD workflows, enabling comprehensive change management capabilities.\n\nLearn more about Neo4j: https://bit.ly/47jnNRL\n#Python #Neo4j #graphdatabase",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UGt3u0htTmk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/UGt3u0htTmk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/UGt3u0htTmk/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/UGt3u0htTmk/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/UGt3u0htTmk/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 10,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'UGt3u0htTmk'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'K_dtlTF-c7f4EfmSOAE3_uWq-Vs',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLnNxbm0wMTR2QjFR',
#    'snippet': {'publishedAt': '2023-10-27T10:07:39Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': "Nodes 2023 - Neo4j's Product Vision and Roadmap - Sudhir Hasbe, CPO Neo4j",
#     'description': 'In this session, Sudhir will introduce the #Neo4j Product Vision and Roadmap and also announce new product capabilities. Sudhir will share product investments over next few years that will make Neo4j the most scalable Graph Database & Analytics Platform, well integrated on all 3 Cloud Providers. Neo4j will make it easy to get started and get value from graphs within a few minutes and scale out and up according to your needs. \n\nYou can see his slides here: https://bit.ly/49h1wpn\nJoin Sudhir for this exciting journey into the future!\n\n\n#neo4j #graphdatabase #cloud #visualisation #datascience #ai',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sqnm014vB1Q/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/sqnm014vB1Q/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/sqnm014vB1Q/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/sqnm014vB1Q/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/sqnm014vB1Q/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 11,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'sqnm014vB1Q'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'oQ9Lbp6bGOB5TtxRHGJmC1RDfMA',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLmZXVXpTTXpTQVUw',
#    'snippet': {'publishedAt': '2023-10-27T06:46:57Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'NODES 2023: Build Apps with the new GenAI Stack from Docker, LangChain, Ollama, and Neo4j',
#     'description': 'From Zero to Database-backed Support Bot - Using the new GenAI Stack from Docker, LangChain, Ollama, and Neo4j With the breakthrough of large language models, adding generative AI capabilities to your applications is now possible for every developer. But where to start? In a partnership between Docker, Neo4j, LangChain, and Ollama we created a GenAI Stack for building database backed GenAI applications. Just with a single "docker-compose up", you get them up and running and can start importing data and creating vector embeddings as well as using an example chatbot application to answer natural language questions using a combination of a Large Language Model and a Knowledge Graph. In this session, we will look behind the scenes into the containers of the GenAI Stack, how they work together and how the LangChain and Streamlit Python apps are implemented. We will use data from StackOverflow, so you can fetch topics that you\'re interested in. But we will not stop there! Based on the existing code we will build and run our own GenAI app that extends the existing functionality and thanks to the quick Docker setup, you can code along. This should give you the setup, confidence and convenience to get going with your first applications that use large language models.\n\nWatch all NODES 2023 sessions: https://dev.neo4j.com/nodes-2023\n\n#neo4j #graphdatabase #nodes2023 #genai #docker #langchain #ollama #appdevelopment',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fWUzSMzSAU0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fWUzSMzSAU0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fWUzSMzSAU0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/fWUzSMzSAU0/sddefault.jpg',
#       'width': 640,
#       'height': 480}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 12,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'fWUzSMzSAU0'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'DdDk8m--2NuIVPhDbXtbRlwiHjY',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLjg2MUVlN1NxXzZj',
#    'snippet': {'publishedAt': '2023-10-27T03:38:15Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'NODES 2023: Graphs vs. Tables: Compare the Reality of Data Around You',
#     'description': "Not all data models are created equal. Some are more rigid and structured, while others are more flexible and easy to understand. In this session, Kateryna compares data models and reveals the effectiveness of graphs versus tables in revealing patterns. You'll gain a clear understanding of the difference between the two data models and how the graph view allows you to uncover hidden patterns and unlock valuable insights much more intuitively compared to the table view.\n\nWatch all NODES 2023 sessions: https://dev.neo4j.com/nodes-2023\n\n#neo4j #graphdatabase #nodes2023 #datamodeling",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/861Ee7Sq_6c/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/861Ee7Sq_6c/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/861Ee7Sq_6c/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/861Ee7Sq_6c/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/861Ee7Sq_6c/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 13,
#     'resourceId': {'kind': 'youtube#video', 'videoId': '861Ee7Sq_6c'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'QBoSqEMC-3Douw_VB5u1Jmj3Lpc',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLng5R05CS3dpTmJv',
#    'snippet': {'publishedAt': '2023-10-26T23:56:19Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'NODES 2023: Knowledge Graph-Based Chatbot',
#     'description': 'Large Language Models (LLMs) like ChatGPT has inspired the world and started a new AI revolution. However, it seems that the latest trend is supplying ChatGPT with external information to increase its accuracy and give it the ability to answer questions where the answers are not present in public datasets. In this session, Tomaz will demonstrate how using a knowledge graph as a storage object for answers gives you explicit and complete control over the answers provided by the chatbot and helps avoid hallucinations.\n\nWatch all NODES 2023 sessions: https://dev.neo4j.com/nodes-2023\n\n#neo4j #graphdatabase #nodes2023 #chatbot #knowledgegraphs',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/x9GNBKwiNbo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/x9GNBKwiNbo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/x9GNBKwiNbo/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/x9GNBKwiNbo/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/x9GNBKwiNbo/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 14,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'x9GNBKwiNbo'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'R6eQscykp5uPSYQ7tEU1EkApRFo',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLmZ5aUQ2NjVKSktz',
#    'snippet': {'publishedAt': '2023-10-26T20:29:00Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'NODES 2023: Solving (Historical) Research Issues With NeoDash',
#     'description': 'In this session, Guido will present how using NeoDash visualization in conjunction with a graph database can be a powerful tool for tackling intricate problems in historical and scientific research. Data in these fields are often scattered across the globe, residing in online databases with unique structures and semantics or only partially digitized within books. The task of linking these diverse sources with Linked Open Data presents its challenges. Guido will introduce the "superconnector" – a knowledge graph designed to consolidate these disparate data sources, enhancing accessibility for researchers. The project to be discussed involves the compilation of data for 3,700 printers and publishers into well-structured profiles. By joining this session, you will gain a forward-looking perspective on leveraging graph databases and visualization tools to address research complexities.\n\nWatch all NODES 2023 sessions: https://dev.neo4j.com/nodes-2023\n\n#neo4j #graphdatabase #nodes2023 #research',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fyiD665JJKs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fyiD665JJKs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fyiD665JJKs/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/fyiD665JJKs/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/fyiD665JJKs/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 15,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'fyiD665JJKs'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'lQtZ9WRvUlZInVhQlE5le_ju-T0',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLnVZYmE3SmIzMUdj',
#    'snippet': {'publishedAt': '2023-10-26T19:09:07Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'NODES 2023: OpenScreening: A Neo4j-Powered Free Compliance Investigation Tool',
#     'description': 'It’s more important than ever to know who you’re in business with. In this session, you will learn how open data about company ownership, sanctioned entities, and graph analytics can be combined to spot compliance risks.\n\nWatch all NODES 2023 sessions: https://dev.neo4j.com/nodes-2023\n\n#neo4j #graphdatabase #nodes2023 #visualisation #compliance #investigation',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uYba7Jb31Gc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/uYba7Jb31Gc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/uYba7Jb31Gc/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/uYba7Jb31Gc/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/uYba7Jb31Gc/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 16,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'uYba7Jb31Gc'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'swewgaUU9Fpm7TIpEWafmRS52BI',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLmZEbGtPbDNDSlQ0',
#    'snippet': {'publishedAt': '2023-10-26T17:18:23Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'NODES 2023: Graph Algorithms for Privacy and Fairness in the Healthcare Industry',
#     'description': 'With a growing range of frauds in the healthcare industry ranging up to 3-10% of total spending in the US, it is essential for healthcare ecosystem not only to protect sensitive healthcare records but also to minimize transactions that are anomalous. On the other hand, regulatory practices prompt us to remove bias and discriminatory recommendations, which often result in poor treatment, inaccurate diagnoses, or leading to delays in diagnosis. In this session, Sharmistha will bring forth how Responsible AI concepts can be extended to graph algorithms in the healthcare industry. The talk highlights two important pillars of Responsible AI, privacy and fairness, which helps deal with fraud and bias in the healthcare field. Sharmistha will provide detailed insights on necessary techniques and algorithms on graphs to curb discriminatory practices and fraud. Furthermore, she will demonstrate a simple use case of product recommendations using Neo4j Graph Data Science that can be extended to provide services such as nutritional diet plans, medications, treatment plans, diagnoses/disease predictions, physical activities, and other healthcare services.\n\nWatch all NODES 2023 sessions: https://dev.neo4j.com/nodes-2023\n\n#neo4j #graphdatabase #nodes2023 #healthcare #lifescience #algorithm',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fDlkOl3CJT4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fDlkOl3CJT4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fDlkOl3CJT4/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/fDlkOl3CJT4/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/fDlkOl3CJT4/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 17,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'fDlkOl3CJT4'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '99EIdxC361ZEpToJevEcilw5OeQ',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLjBjQUFSY3JEekw4',
#    'snippet': {'publishedAt': '2023-10-26T16:13:04Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'IA générative et Neo4j : APOC & LLM (10 min)',
#     'description': 'IA générative et Neo4j\nL’IA de confiance\n\nDémo APOC & LLM',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0cAARcrDzL8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/0cAARcrDzL8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/0cAARcrDzL8/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/0cAARcrDzL8/sddefault.jpg',
#       'width': 640,
#       'height': 480}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 18,
#     'resourceId': {'kind': 'youtube#video', 'videoId': '0cAARcrDzL8'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'pgH5Nv924ehkjhpXFTzCq_jb_OY',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLlhYNVVmNHl3dG5R',
#    'snippet': {'publishedAt': '2023-10-25T08:05:53Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'Neo4j Live: Testcontainers with Neo4j',
#     'description': "We'll look at some of the issues with previous testing approaches, then show how Testcontainers improve those. We'll also get a look at working through issues and discuss native image testing - when it makes sense and when it doesn't.\n\nGuests: Oleg Šelajev, Atomicjar & Michael Simons, Neo4j\n\n#neo4j #graphdatabase #testing #container",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XX5Uf4ywtnQ/default_live.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XX5Uf4ywtnQ/mqdefault_live.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XX5Uf4ywtnQ/hqdefault_live.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/XX5Uf4ywtnQ/sddefault_live.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/XX5Uf4ywtnQ/maxresdefault_live.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 19,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'XX5Uf4ywtnQ'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'g-_ymZOGAJTqKnI7K4IWzrbMnw0',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLmpqdVlhSWdoNElR',
#    'snippet': {'publishedAt': '2023-10-24T14:12:11Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'NODES Streaming Test',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/jjuYaIgh4IQ/default_live.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/jjuYaIgh4IQ/mqdefault_live.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/jjuYaIgh4IQ/hqdefault_live.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/jjuYaIgh4IQ/sddefault_live.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/jjuYaIgh4IQ/maxresdefault_live.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 20,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'jjuYaIgh4IQ'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'crS46LG_Yq4pC04l73kafW6L3ig',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLlVfclEyU1JNZnlV',
#    'snippet': {'publishedAt': '2023-10-20T04:15:04Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'Neo4j Live: Kubernetes Deployment',
#     'description': 'In this episode we are looking at migrating Neo4j from v4 to v5 and how to deploy Neo4j on Kubernetes. We are looking at automated backups in your own data system by using Kubernetes Cronjob.\n\nGuest: Jennifer Abel, Software Developer at synyx GmbH & Co. KG\n\nBlog: https://synyx.de/blog/deploy-neodash-on-kubernetes/\n\n#neo4j #graphdatabase #kubernetes #deployment',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/U_rQ2SRMfyU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/U_rQ2SRMfyU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/U_rQ2SRMfyU/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/U_rQ2SRMfyU/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/U_rQ2SRMfyU/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 21,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'U_rQ2SRMfyU'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '5Y5vwAwoVKffCay5U4JraDJYvn4',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLmVPWWJwTmhibGZz',
#    'snippet': {'publishedAt': '2023-10-17T03:04:21Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'Discover Neo4j AuraDB Free with Michael and Alexander - NODES 2023 Special',
#     'description': 'Neo4j AuraDB Free: http://dev.neo4j.com/discover-aura\n\nCatch-up on missed episodes from the repo! \nhttps://github.com/neo4j-examples/discoveraurafree\n\nMichael: https://twitter.com/mesirii/\nAlexander: https://twitter.com/alexandererdl\n\nAll previous episodes: https://neo4j.com/video/discover-aura-free-with-fun-datasets/\nCheck out https://community.neo4j.com/ for questions and discussions around Neo4j\n\nRegister for NODES 2023 https://dev.neo4j.com/NODES2023\nNeoDash: https://neo4j.com/labs/neodash/\n\n#cloud #neo4j #graphdatabase #datasets #conference #agenda',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/eOYbpNhblfs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/eOYbpNhblfs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/eOYbpNhblfs/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/eOYbpNhblfs/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/eOYbpNhblfs/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 22,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'eOYbpNhblfs'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'Ojm17u1p-W_An8NcEqGGdZph4F0',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLkNtN1FIRkVUb1ZZ',
#    'snippet': {'publishedAt': '2023-10-13T01:20:39Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'Neo4j Live: NODES 2023 Speaker Roundtable',
#     'description': "Join us for a live Speaker Panel with select guests from 2023's NODES conference coming in October. Guests include:\n\nStephen Mc Gowan: \nSpeaker of the session titled: Regulation Can Be Fun! Building Insightful Knowledge Graphs Using Domain-Specific Languages\n\nKateryna Nesvit: \nGraphs vs. Tables: Compare the Reality of Data Around You\n\nGuido Thys:\nSolving (Historical) Research Issues With NeoDash\n\nElena Kohlwey:\nUnleash the Magic of User-Defined Procedures\n\nRegister for NODES 2023 https://dev.neo4j.com/NODES2023",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Cm7QHFEToVY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Cm7QHFEToVY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Cm7QHFEToVY/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/Cm7QHFEToVY/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/Cm7QHFEToVY/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 23,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'Cm7QHFEToVY'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'Qz8fu7K91ds0Nts-iKd4_CDGbvc',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLjE2ZDNybk5sTlVV',
#    'snippet': {'publishedAt': '2023-10-10T17:18:40Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'Road to NODES: Analyzing The Physical World With Graphs & Neo4j',
#     'description': 'In this workshop, you’ll learn to apply graphs to geospatial data science workflows. You’ll go from data importing to using Graph Data Science functionality and visualizations.\n\nSlides: https://bit.ly/nodes23geo\nSandbox: https://dev.neo4j.com/try\nNews Graph: https://github.com/johnymontana/news-graph\nGeospatial Cheat Sheet: https://lyonwj.com/blog/spatial-cypher-cheat-sheet\nHydrobasins: https://www.hydrosheds.org/products/hydrobasins\nWater Graph: https://github.com/johnymontana/water-graph\n\nRegister for NODES 2023 https://dev.neo4j.com/NODES2023\n\nCheck out https://community.neo4j.com/ for questions and discussions around Neo4j\n\n#neo4j #graphdatabase #geography #geospatial #workshop',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/16d3rnNlNUU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/16d3rnNlNUU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/16d3rnNlNUU/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/16d3rnNlNUU/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/16d3rnNlNUU/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 24,
#     'resourceId': {'kind': 'youtube#video', 'videoId': '16d3rnNlNUU'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'R2pImJmM-Z1Em1a7EdGvPW7L5qg',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLm5WMy1LS0VabkQ0',
#    'snippet': {'publishedAt': '2023-10-10T02:15:27Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'Neo4j with Amazon Bedrock.',
#     'description': 'In this video, Lee Razo shows how to use Neo4j with Amazon Bedrock.  \n\nHe demonstrates parsing semi-structured data with generative AI to build a knowledge graph.  Then, he shows how to layer a chatbot over that Neo4j-powered #knowledgegraph using #GenAI\n\nThe demo code is available on GitHub here: https://bit.ly/46CrTns\n\n#amazonbedrock',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nV3-KKEZnD4/default.jpg',
#       'width': 120,
#       'height': 90},
# ...
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nbY0KoT54uE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/nbY0KoT54uE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/nbY0KoT54uE/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/nbY0KoT54uE/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/nbY0KoT54uE/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 43,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'nbY0KoT54uE'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'ppO72DgRha8eDXjyV_pN6XuothU',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLllZLXVnQUhQdTRN',
#    'snippet': {'publishedAt': '2023-08-04T04:16:19Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'Neo4j Live: Lessons learned from Real-World Graph App Development',
#     'description': "In this episode, we dive into the realm of real-world Graph Application Development.\r\n\r\nWe cover key topics such as Cypher optimisation, the nuances of data importing and practical graph data modelling. Moreover, we explore techniques for enhancing performance and memory optimisation. Dave Aitel will tell from personal history what he learned since developing with Neo4j and passes on some valuable lessons to help you navigate the complex landscape of graph app development and achieve optimal results.\n\nDave's Presentation: https://prezi.com/view/EWHE6Y6nUU8R8iGcOD7f/\n\nReagent Blog: https://margin.re/2023/06/entity-resolution-in-reagent/\n\nLessons Learned: \ncoalesce: https://neo4j.com/docs/cypher-manual/current/functions/scalar/#functions-coalesce\nperiodic iterate: https://neo4j.com/docs/apoc/current/overview/apoc.periodic/apoc.periodic.iterate/\nunwind: https://neo4j.com/docs/cypher-manual/current/clauses/unwind/\nQuery Planer: https://neo4j.com/docs/cypher-manual/current/query-tuning/query-profile/\nIndexes: https://neo4j.com/docs/cypher-manual/current/indexes-for-search-performance/\nConstraints: https://neo4j.com/docs/cypher-manual/current/constraints/\n\n0:00 Welcome\n3:45 Intro\n6:09 Overview of Building Graph Applications\n14:50 Lesson1: Data Import  \n31:50 Lesson2: Graph Projections\n42:02 Lesson3: Cartesian Products / Combinatorial Explosions\n46:55 Lesson4: Query Planner \n50:15 Lesson5: Indexes\n53:50 Conclusion \n55:45 Q&A\n1:07:50 Wrap-Up\n\nNeo4j Discord https://dev.neo4j.com/chat\r\n\r\n#neo4j #graphdatabase #app #development #lessonslearned #bestpractice",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/YY-ugAHPu4M/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/YY-ugAHPu4M/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/YY-ugAHPu4M/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/YY-ugAHPu4M/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/YY-ugAHPu4M/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 44,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'YY-ugAHPu4M'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'Z5DhAnCqJWdxhfmrAcC5i5-LIAA',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLnhLXzA3Y3FLd01r',
#    'snippet': {'publishedAt': '2023-08-02T04:19:43Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'Going Meta Ep 19: Ontology Versioning in Neo4j',
#     'description': 'Episode 19 of Going Meta - A Series on Graphs, Semantics and Knowledge \r\n\r\nJesús Barrasa: https://twitter.com/BarrasaDV\r\nRepository: https://github.com/jbarrasa/goingmeta\r\nPrevious episodes: https://neo4j.com/video/going-meta-a-series-on-graphs-semantics-and-knowledge/\nProtege: https://webprotege.stanford.edu/\nNeo4j Sandbox https://dev.neo4j.com/try\nNeosemantics (n10s): https://neo4j.com/labs/neosemantics/\nNeoDash: https://neo4j.com/labs/neodash/\nKnowledge Graph Book: https://neo4j.com/knowledge-graphs-practitioners-guide/\n\n0:00 Welcome\n4:49 Intro to Ontology Versioning\n21:10 Composite Graph Versioning\n48:58 Version Updating within one Graph\n58:38 Q&A\n1:09:15 Wrap-Up\n\r\n\r\nCheck out https://community.neo4j.com/ for questions and discussions around Neo4j\r\n\r\n#neo4j #graphdatabase #semantic #knowledgegraph #rdf #semantics #version #ontology',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xK_07cqKwMk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/xK_07cqKwMk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/xK_07cqKwMk/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/xK_07cqKwMk/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/xK_07cqKwMk/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 45,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'xK_07cqKwMk'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'gI7QMWsePp6f50WSoOiDV19QuXk',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLjhEVXBraHFaaXhN',
#    'snippet': {'publishedAt': '2023-07-31T21:10:01Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'Best of: Pay Gap Data - Discovering Neo4j AuraDB Free with Michael and Alexander',
#     'description': 'Best of Discover AuraDB Free with previously broadcast episodes! \r\n\r\nNeo4j AuraDB Free: http://dev.neo4j.com/discover-aura\r\n\r\nCatch-up on missed episodes from the repo! \r\nhttps://github.com/neo4j-examples/discoveraurafree\r\n\r\nUK Gender Pay Gap Data: https://gender-pay-gap.service.gov.uk/\r\nKaggle Gender Pay Gap Dataset: https://www.kaggle.com/datasets/fedesoriano/gender-pay-gap-dataset\r\nNeodash: https://neo4j.com/labs/neodash/\r\nPayGap App: https://twitter.com/PayGapApp\r\n\r\nMichael: https://twitter.com/mesirii/\r\nAlexander: https://twitter.com/alexandererdl\r\n\r\nAll previous episodes: https://neo4j.com/video/discover-aura-free-with-fun-datasets/\r\nCheck out https://community.neo4j.com/ for questions and discussions around Neo4j\r\n\r\n#cloud #neo4j #graphdatabase #datasets #equality #paygap #women\r\n\r\nimage: https://www.libela.org/preko-plota/5787-zene-u-srbiji-skolovanije-a-zaradjuju-manje-od-muskaraca/',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8DUpkhqZixM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/8DUpkhqZixM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/8DUpkhqZixM/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/8DUpkhqZixM/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/8DUpkhqZixM/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 46,
#     'resourceId': {'kind': 'youtube#video', 'videoId': '8DUpkhqZixM'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'bTe-Hc89EZ1F2dcD168yf3aQNFc',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLlh4YlJFQlhFYlZ3',
#    'snippet': {'publishedAt': '2023-07-26T07:59:54Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'Neo4j Live: Lessons learned from Real-World Graph App Development #shorts',
#     'description': 'Watche the full epsiode live or on demand: https://youtube.com/live/YY-ugAHPu4M \n\nIn this episode, we dive into the realm of real-world Graph Application Development.\n\nWe cover key topics such as Cypher optimisation, the nuances of data importing and practical graph data modelling. Moreover, we explore techniques for enhancing performance and memory optimisation. Dave Aitel will tell from personal history what he learned since developing with Neo4j and passes on some valuable lessons to help you navigate the complex landscape of graph app development and achieve optimal results.\n \n#neo4j #graphdatabase #app #development #lessonslearned #bestpractice #shorts  \n\nMusic: https://pixabay.com/music/corporate-modern-technology-theme-155582/',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XxbREBXEbVw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XxbREBXEbVw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XxbREBXEbVw/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/XxbREBXEbVw/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/XxbREBXEbVw/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 47,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'XxbREBXEbVw'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'ukgpeIu8Nf4gC0mhnAFb9D1YAUA',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLjI3Y2IzVTRSd3Q0',
#    'snippet': {'publishedAt': '2023-07-25T03:03:23Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'Best of: Genealogy - Discover Neo4j AuraDB Free with Michael and Alexander',
#     'description': 'Best of Discover AuraDB Free with previously broadcast episodes! \r\n\r\nNeo4j AuraDB Free: http://dev.neo4j.com/discover-aura\r\n\r\nCatch-up on missed episodes from the repo! \r\nhttps://github.com/neo4j-examples/discoveraurafree\r\n\r\nBlog: https://medium.com/@mesirii/cc8d69977102\r\nHamilton in Neo4j: https://github.com/jexp/hamilton-graph/blob/main/readme.adoc \r\n\r\nMichael: https://twitter.com/mesirii/\r\nAlexander: https://twitter.com/alexandererdl\r\n\r\nAll previous episodes: https://neo4j.com/video/discover-aura-free-with-fun-datasets/\r\nCheck out https://community.neo4j.com/ for questions and discussions around Neo4j\r\n\r\n#cloud #neo4j #graphdatabase #datasets #genealogy #family #familytree',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/27cb3U4Rwt4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/27cb3U4Rwt4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/27cb3U4Rwt4/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/27cb3U4Rwt4/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/27cb3U4Rwt4/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 48,
#     'resourceId': {'kind': 'youtube#video', 'videoId': '27cb3U4Rwt4'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'sP1p1Cp4RS5R8Um6eoyfxi0YmmE',
#    'id': 'VVV2emUzaFU2T1pCa0IxdmtoSDJsSDlRLjNQTy1lckFQNlI0',
#    'snippet': {'publishedAt': '2023-07-19T16:02:19Z',
#     'channelId': 'UCvze3hU6OZBkB1vkhH2lH9Q',
#     'title': 'Azure OpenAI Neo4j Demo',
#     'description': "In this demo, Ezhil shows how #Neo4j works with the Microsoft Azure OpenAI Service.  The data flow consists of two parts:\n\n(1) Using generative AI to parse a data set, extract entities and relationships from it, and then create Neo4j Cypher queries against the database that populate it, creating a knowledge graph\n(2) We put a chat bot over the knowledge graph so non technical users can interact, without needing to learn a database query language.\n\nThe code is available on GitHub here if you'd like to try the demo yourself: https://github.com/neo4j-partners/intelligent-medical-assistant\n\n#Azure #Neo4j #GenAI #OpenAI #microsoftazure",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3PO-erAP6R4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/3PO-erAP6R4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/3PO-erAP6R4/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/3PO-erAP6R4/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/3PO-erAP6R4/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo4j',
#     'playlistId': 'UUvze3hU6OZBkB1vkhH2lH9Q',
#     'position': 49,
#     'resourceId': {'kind': 'youtube#video', 'videoId': '3PO-erAP6R4'},
#     'videoOwnerChannelTitle': 'Neo4j',
#     'videoOwnerChannelId': 'UCvze3hU6OZBkB1vkhH2lH9Q'}}],
#  'pageInfo': {'totalResults': 1897, 'resultsPerPage': 50}}

# %%
len(vids['items'])
# Out:
# 50

# %%
vids['items'][0]['snippet']['resourceId']['videoId']
# Out:
# 'BP9nATW3y_M'

# %%
def get_video_addresses(next_page_token: str = None, total_results: int = -1, videos: List[str] = []) -> List[str]:
        
    channel_id = "UCvze3hU6OZBkB1vkhH2lH9Q"
    api_key = os.environ.get("YOUTUBE_API_KEY")
    uploads_id = "UUvze3hU6OZBkB1vkhH2lH9Q"

    address = f"https://www.googleapis.com/youtube/v3/playlistItems?playlistId={uploads_id}&key={api_key}&part=snippet&maxResults=50"
    
    if not next_page_token:
      vid_req = requests.get(address)

    else:
        vid_req = requests.get(address+f'&pageToken={next_page_token}')
        
    vids = vid_req.json()

    if total_results == -1:
        total_results = vids['pageInfo']['totalResults']
        print('total results set: ', total_results)

    videos += [x['snippet']['resourceId']['videoId'] for x in vids['items']]

    print("total results: ", total_results)
    print("ids retrieved: ", len(videos), "\n")

    if "nextPageToken" not in vids.keys():
        print("complete")
        return videos
    
    next_page_token = vids['nextPageToken']

    get_video_addresses(next_page_token=next_page_token, total_results=total_results, videos=videos)

    return videos

# %%
video_ids = get_video_addresses()
# Out:
# total results set:  1897
# total results:  1897
# ids retrieved:  50
#
# total results:  1897
# ids retrieved:  100
#
# total results:  1897
# ids retrieved:  150
#
# total results:  1897
# ids retrieved:  200
#
# total results:  1897
# ids retrieved:  250
#
# total results:  1897
# ids retrieved:  300
#
# total results:  1897
# ids retrieved:  350
#
# total results:  1897
# ids retrieved:  400
#
# total results:  1897
# ids retrieved:  450
#
# total results:  1897
# ids retrieved:  500
#
# total results:  1897
# ids retrieved:  550
#
# total results:  1897
# ids retrieved:  600
#
# total results:  1897
# ids retrieved:  650
#
# total results:  1897
# ids retrieved:  700
#
# total results:  1897
# ids retrieved:  750
#
# total results:  1897
# ids retrieved:  800
#
# total results:  1897
# ids retrieved:  850
#
# total results:  1897
# ids retrieved:  900
#
# total results:  1897
# ids retrieved:  950
#
# total results:  1897
# ids retrieved:  1000
#
# total results:  1897
# ids retrieved:  1050
#
# total results:  1897
# ids retrieved:  1100
#
# total results:  1897
# ids retrieved:  1150
#
# total results:  1897
# ids retrieved:  1200
#
# total results:  1897
# ids retrieved:  1250
#
# total results:  1897
# ids retrieved:  1300
#
# total results:  1897
# ids retrieved:  1350
#
# total results:  1897
# ids retrieved:  1400
#
# total results:  1897
# ids retrieved:  1450
#
# total results:  1897
# ids retrieved:  1500
#
# total results:  1897
# ids retrieved:  1550
#
# total results:  1897
# ids retrieved:  1600
#
# total results:  1897
# ids retrieved:  1650
#
# total results:  1897
# ids retrieved:  1700
#
# total results:  1897
# ids retrieved:  1750
#
# total results:  1897
# ids retrieved:  1800
#
# total results:  1897
# ids retrieved:  1850
#
# total results:  1897
# ids retrieved:  1897
#
# complete

# %%
video_ids[:10]
# Out:
# ['BP9nATW3y_M',
#  'MQTVDGOiWBY',
#  'vvn1WUgqxqM',
#  '70V9TIYvqrw',
#  'pQWEgpNwY2w',
#  'DQ-SShCGVzs',
#  'Znd4k64JRFc',
#  '9DxwgIKVSHY',
#  'm51Dtppb2h0',
#  '_cC2PoOJHQc']

# %%
full_video_addresses = ["https://www.youtube.com/watch?v="+id for id in video_ids]

# %%
full_video_addresses[:10]
# Out:
# ['https://www.youtube.com/watch?v=BP9nATW3y_M',
#  'https://www.youtube.com/watch?v=MQTVDGOiWBY',
#  'https://www.youtube.com/watch?v=vvn1WUgqxqM',
#  'https://www.youtube.com/watch?v=70V9TIYvqrw',
#  'https://www.youtube.com/watch?v=pQWEgpNwY2w',
#  'https://www.youtube.com/watch?v=DQ-SShCGVzs',
#  'https://www.youtube.com/watch?v=Znd4k64JRFc',
#  'https://www.youtube.com/watch?v=9DxwgIKVSHY',
#  'https://www.youtube.com/watch?v=m51Dtppb2h0',
#  'https://www.youtube.com/watch?v=_cC2PoOJHQc']

# %%
df = pd.DataFrame({"YouTube_Address": full_video_addresses})

# %%
df.to_csv("YouTube_Addresses.csv")

# %% [markdown]
# ## Upload to GCP Storage

# %%
from google.cloud import storage
from google.oauth2 import service_account

# %%
credentials = service_account.Credentials.from_service_account_file(
    os.environ.get('GCP_SERVICE_ACCOUNT_KEY_PATH')
)

storage_client = storage.Client(credentials=credentials)
bucket = storage_client.get_bucket("agent-neo-neo4j-cs-team-201901-docs")
file_loc = "youtube/"

# %%
videos_df = pd.read_csv("YouTube_Addresses.csv")['YouTube_Address']
videos_df.head()
# Out:
# 0    https://www.youtube.com/watch?v=BP9nATW3y_M
# 1    https://www.youtube.com/watch?v=MQTVDGOiWBY
# 2    https://www.youtube.com/watch?v=vvn1WUgqxqM
# 3    https://www.youtube.com/watch?v=70V9TIYvqrw
# 4    https://www.youtube.com/watch?v=pQWEgpNwY2w
# Name: YouTube_Address, dtype: object

# %%
bucket.blob(file_loc+"neo4j_video_list.csv").upload_from_string(videos_df.to_csv(), 'text/csv')

# %% [markdown]
# ## Retrieve from GCP Storage

# %%
import io

# %%
videos_temp = bucket.get_blob(file_loc+"neo4j_video_list.csv")
videos_temp = videos_temp.download_as_string()
videos_df = pd.read_csv(io.BytesIO(videos_temp))['YouTube_Address']

# %%
url_list = videos_df.to_list()

# %% [markdown]
# ## Get Transcripts

# %% [markdown]
# Test with just the first video

# %%
id = videos_df.iloc[0].replace("https://www.youtube.com/watch?v=", "")

# %%
raw_transcript = YouTubeTranscriptApi.get_transcript(id)

# %%
# instantiate the text formatter
formatter = TextFormatter()

# format the video into a string without timestamps, etc...
transcript_formatted = formatter.format_transcript(raw_transcript)

# %%
# replace newlines with a space 
transcript_formatted = transcript_formatted.replace("\n", " ")

# %%
print(f'the text is {len(transcript_formatted.split())} words long')
print(f'the text is {len(transcript_formatted)} characters long')
# Out:
# the text is 5766 words long
# the text is 28819 characters long

# %%
def create_transcript(video_id: str) -> str:
    """
    This method retrieves the video transcript and formats it.
    """

    raw_transcript = YouTubeTranscriptApi.get_transcript(id)
    # instantiate the text formatter
    formatter = TextFormatter()

    # format the video into a string without timestamps, etc...
    transcript_formatted = formatter.format_transcript(raw_transcript)

    # replace newlines with a space 

    return transcript_formatted.replace("\n", " ")

# %%
test_transcript = create_transcript(id)

# %% [markdown]
# ## Upload Transcripts to GCP Storage

# %%
file_loc = "youtube/transcripts/"

# %%
bucket.blob(file_loc+id+".txt").upload_from_string(test_transcript, 'text/plain')

# %%
def upload_transcript(transcript: str, id: str) -> None:
    """
    This method uploads a transcript to GCP Storage.
    Uploading a file will automatically overwrite any existing file with the same id in storage.
    """

    file_loc = "youtube/transcripts/"
    bucket.blob(file_loc+id+".txt").upload_from_string(transcript, 'text/plain')

# %%
upload_transcript(test_transcript, id)

# %% [markdown]
# ## Download Transcripts

# %%
def get_transcript_addresses(bucket_name: str) -> List[str]:
    """
    This method downloads a transcript from GCP storage. 
    """

    blobs = storage_client.list_blobs(bucket_name, prefix="youtube/transcripts/")

    for b in blobs:
        print(b.name)

# %%
get_transcript_addresses("agent-neo-neo4j-cs-team-201901-docs")
# Out:
# youtube/transcripts/
# youtube/transcripts/BP9nATW3y_M.txt

# %%
def get_transcript_text(address: str) -> str:
    """
    This method gets the transcript text from the GCP storage bucket address.
    """

    temp = bucket.get_blob(address).download_as_text()
    
    return temp

# %%
get_transcript_text(address="youtube/transcripts/BP9nATW3y_M.txt")
# Out:
# "okay so uh we are going to do a very quick overview today it'll be fast and furious um but uh feel free to reach out to us afterward if you have questions um or want to discuss this with us further um we've got all code available and of course this video will be made available afterward as well my name is Jennifer E and I'm Mark Heckler and we're happy to be here with you today yep so I'm a developer Advocate at neo4j um I like writing uh code and then I like uh sharing that and and kind of sharing my learning process or kind of what's behind it through technical writing so I write a lot of blog posts I speak at a lot of conferences or or virtual events um and then just outside of that I'm just kind of a geek in general most things geek I kind of enjoy so and I'm Mark Heckler I'm a principal Cloud advocate of java and jvm languages with Microsoft also picked up a few Awards and honors along the way Java Champion Java 1 Rockstar groundbreaker Ambassador C developer expert uh wrote a book uh which you see there and I'm a licensed instrument rated pilot which I don't think we talk about today which is a real shame but oh well you know such as life so a little bit on this session uh again it's going to be a bit of a whirlwind but we are going to kind of take just dip our toes into the water of using spring Ai and this is going to bring a I2 spring applications uh if the name doesn't H at that already um they have both emble and for open AI as well as as your open AI um and it takes text based prompts and turns it into language or code uh for return results we're going to use the technique called prompt stuffing there's also one called fine-tuning but we're not going to go quite that deep and and integrated yet um so we're just GNA kind of stick with the prompt stuffing and we're going to do that through retrieval augmented generation or rag if you see that term quite a bit when you when you see things about knowledge WPS or llms um what it's going to do is provide context and guidance for the llm to return uh more contextual and valid results and verify the results so that there's less chance of hallucination there and I will say that we do a lot more things that we're not going to be able to cover today which is kind of a shame but uh but that's why we want you to check out the repo and just to Ping us after the fact because there's a lot of things that go into various different aspects of working with with AI in one form or another uh and we don't cover them all but we cover a lot of the high points but within this very short session today we cover the maybe a select few of those high points so uh if you want to talk about this at length after the fact please do reach out we're happy to to discuss absolutely so neo4j is going to be used uh as a a vector database and to add that data context so we added Vector search capabilities uh to neo4j earlier in the year um I should say neo4j did and it's going to help us ground the LM Answers by using the connected data stored in the graph so you're going to have a prompt it's going to be used to feed a query which is going to retrieve graph data and that all is going to be fed to the AI so the typical steps um you would calculate vectors or store embeddings in neo4j you would have the prompt um that then would get calculated up and sent over to the AI with the data the graph data um and then then it would compare the data that's in that prompt um to vectors stored in the llm return the most similar um if you want to know more about neo4j Vector search or the capabil ities that are available there and how that works um feel free to check out the link again the slides will be made available um and you can click the link and learn more about how neo4j is using uh vectors uh in their database so without further Ado let's dive into some code okay so as Jennifer mentioned this is kind of a whirlwind tour uh so we we are trying to be very judicious with the time oh that we've got the Inception ...

# %% [markdown]
# ## Create Transcripts and Upload

# %%
unsuccessful = []

for t in url_list[:10]:
    id = t.replace("https://www.youtube.com/watch?v=", "")
    try:
        transcript = create_transcript(id)
        upload_transcript(transcript=transcript, id=id)
        print("Video "+id+" Uploaded to GCP Storage.")
    except Exception as e:
        unsuccessful+=[id]

print("Unsuccessful ids: ", unsuccessful)
# Out:
# Video BP9nATW3y_M Uploaded to GCP Storage.
# Video MQTVDGOiWBY Uploaded to GCP Storage.
# Video vvn1WUgqxqM Uploaded to GCP Storage.
# Video 70V9TIYvqrw Uploaded to GCP Storage.
# Video pQWEgpNwY2w Uploaded to GCP Storage.
# Video DQ-SShCGVzs Uploaded to GCP Storage.
# Video Znd4k64JRFc Uploaded to GCP Storage.
# Video m51Dtppb2h0 Uploaded to GCP Storage.
# Video _cC2PoOJHQc Uploaded to GCP Storage.
# Unsuccessful ids:  ['9DxwgIKVSHY']
