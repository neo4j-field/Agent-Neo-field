# %%
from scrape.scraper.scrape import GCPStorageLoader
import pandas as pd
import json
# Out:
# /Users/alexandergilmore/Documents/GitHub/Agent-Neo-field/venv/lib/python3.11/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.16) or chardet (5.2.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %% [markdown]
# ### init the loader

# %%
loader = GCPStorageLoader()

# %% [markdown]
# ## Iterate through each desired playlist
# - pull and store video id & title
# - get transcripts and upload for each video in playlist
# - chunk transcripts
# - format video info and get embedding of transcript chunk for each chunk
# - upload to Neo4j graph

# %%
with open("scrape/scraper/resources/youtube_playlist_ids.json") as json_file:
    playlists = json.load(json_file)

# %%
playlists
# Out:
# {'Going Meta': 'PL9Hl4pk2FsvX-5QPvwChB-ni_mFF97rCE',
#  'Nodes 2023 GenAI': 'PL9Hl4pk2FsvUOTavg2q_n7vLZmvUCNmS5',
#  'Ask a Data Scientist: Season III': 'PL9Hl4pk2FsvVkj5ZrwtYiiwQVzDB7ZhcC',
#  'Ask a Data Scientist: Season II': 'PL9Hl4pk2FsvU-jJZTe2T6dOCtJse90Oxg',
#  'Neo4j Aura How to Videos': 'PL9Hl4pk2FsvVyzMCg1Dx2dEoX73ewq35j'}

# %%
trouble_playlists = {'Going Meta': 'PL9Hl4pk2FsvX-5QPvwChB-ni_mFF97rCE',
 'Ask a Data Scientist: Season III': 'PL9Hl4pk2FsvVkj5ZrwtYiiwQVzDB7ZhcC',
}

# %%
for title, id in trouble_playlists.items():
    # set playlist id
    loader.playlist_id = id
    loader._scraped_video_info = None
    print(title)
    print(loader.playlist_id)

    print("creating CSV file with video info...")
    # scrape video info for playlist
    loader.scrape_video_info(videos=[])

    print("uploading CSV file to Storage...")
    # upload to Storage
    loader.upload_scraped_video_info(file_name=title)

    print("Creating and uploading transcripts...")
    # create and upload transcripts
    loader.create_and_upload_neo4j_transcripts(transcripts_folder=title, video_info_file_name=title)

    # ignore failed for now

    print()
# Out:
# Going Meta
# PL9Hl4pk2FsvX-5QPvwChB-ni_mFF97rCE
# creating CSV file with video info...
# total results set:  23
# total results:  23
# ids retrieved:  23
#
# complete
# uploading CSV file to Storage...
# Creating and uploading transcripts...
# Progress :  4.35 %
# Failed   :  0
# Progress :  13.04 %
# Failed   :  0
# Progress :  21.74 %
# Failed   :  0
# Progress :  30.43 %
# Failed   :  0
# Progress :  39.13 %
# Failed   :  0
# Progress :  47.83 %
# Failed   :  0
# Progress :  56.52 %
# Failed   :  0
# Progress :  65.22 %
# Failed   :  0
# Progress :  73.91 %
# Failed   :  0
# Progress :  82.61 %
# Failed   :  0
# Progress :  91.3 %
# Failed   :  0
# Progress :  100.0 %
# Failed   :  0
#
# Ask a Data Scientist: Season III
# PL9Hl4pk2FsvVkj5ZrwtYiiwQVzDB7ZhcC
# creating CSV file with video info...
# total results set:  9
# total results:  9
# ids retrieved:  9
#
# complete
# uploading CSV file to Storage...
# Creating and uploading transcripts...
# Progress :  11.11 %
# ...

# %% [markdown]
# ### scrape Neo4j channel for all video ids and titles

# %%
loader.scrape_video_info()
# Out:
# total results set:  1928
# total results:  1928
# ids retrieved:  50
#
# total results:  1928
# ids retrieved:  100
#
# total results:  1928
# ids retrieved:  150
#
# total results:  1928
# ids retrieved:  200
#
# total results:  1928
# ids retrieved:  250
#
# total results:  1928
# ids retrieved:  300
#
# total results:  1928
# ids retrieved:  350
#
# total results:  1928
# ids retrieved:  400
#
# total results:  1928
# ids retrieved:  450
#
# total results:  1928
# ids retrieved:  500
#
# total results:  1928
# ids retrieved:  550
#
# total results:  1928
# ids retrieved:  600
#
# total results:  1928
# ids retrieved:  650
#
# total results:  1928
# ids retrieved:  700
#
# total results:  1928
# ids retrieved:  750
#
# total results:  1928
# ids retrieved:  800
#
# total results:  1928
# ids retrieved:  850
#
# total results:  1928
# ids retrieved:  900
#
# total results:  1928
# ids retrieved:  950
#
# total results:  1928
# ids retrieved:  1000
#
# total results:  1928
# ...

# %% [markdown]
# ### upload to GCP Storage bucket

# %%
loader.upload_scraped_video_info()

# %% [markdown]
# ### create and upload transcripts for each video

# %%
loader.create_and_upload_neo4j_transcripts()
# Out:
# Progress :  0.05 %
# Failed   :  0
# Failed: lBiFiqkhUdc
# Failed: E_JO4-2D5Xs
# Failed: 7h4bKNq29-g
# Failed: fUSM29zN99Y
# Failed: sdNVq757y6s
# Failed: r5Vmg_YX8dk
# Failed: jjuYaIgh4IQ
# Progress :  2.65 %
# Failed   :  7
# Failed: 1CqZo7nP8yQ
# Failed: Pk2tLfxwiD8
# Progress :  5.24 %
# Failed   :  9
# Failed: aHxBMUq511c
# Failed: v-JdvAfRWtQ
# Failed: UaMTkqBl7ws
# Progress :  7.83 %
# Failed   :  12
# Failed: uZszZA5Yjag
# Failed: UWNLY-iPd-0
# Progress :  10.43 %
# Failed   :  14
# Failed: z1DFg74z3WI
# Failed: JocoCwWwKCk
# Failed: pV2Zc-C9Yxg
# Progress :  13.02 %
# Failed   :  17
# Failed: e8Q0OJmMogo
# Failed: i829AD3_wFU
# Failed: was1ZwxLFg8
# Failed: z4WqwAt6mwI
# Failed: Wj8E9omPzro
# Failed: gMYu6OaGUOc
# Progress :  15.61 %
# Failed   :  23
# Failed: Zv-XTQ68fEw
# Failed: Q00XiPkgguU
# Progress :  18.21 %
# Failed   :  25
# Failed: 22l165WHl4Q
# Failed: ufj7wYqHMcw
# Failed: h9Q1FpSQsg8
# Progress :  20.8 %
# Failed   :  28
# Failed: lDjHsZYMC-M
# ...

# %%
loader.update_unsuccessful_transcripts()
